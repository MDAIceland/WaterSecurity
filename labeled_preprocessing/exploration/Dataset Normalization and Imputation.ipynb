# %%
import pandas as pd
import numpy as np
from langdetect import detect as langdetect
import random
seed = 42
np.random.seed(seed)
random.seed(seed)
import sys
sys.path.append("../..")
from data.labeled import CWA as cwa, CWR as cwr

# %% [markdown]
# # Preprocess whole dataset

# %%
cwa.head()
# Out:
#    Account No     Organisation     City                   Country  \
# 0        1093  City of Atlanta  Atlanta  United States of America
# 1        1184   City of Austin   Austin  United States of America
# 2        1184   City of Austin   Austin  United States of America
# 3        1184   City of Austin   Austin  United States of America
# 4        1184   City of Austin   Austin  United States of America
#
#           Region  Access  C40  Reporting Year  \
# 0  North America  public  NaN            2018
# 1  North America  public  C40            2018
# 2  North America  public  C40            2018
# 3  North America  public  C40            2018
# 4  North America  public  C40            2018
#
#          Risks to city's water supply  \
# 0  Increased water stress or scarcity
# 1  Increased water stress or scarcity
# 2  Increased water stress or scarcity
# 3  Increased water stress or scarcity
# 4  Increased water stress or scarcity
#
#                                    Adaptation action  \
# 0  Investment in existing water supply infrastruc...
# 1               Conservation awareness and education
# 2                            Conservation incentives
# 3                             Water use restrictions
# 4                Efficiency regulations or standards
#
#                                   Action description        City Location
# 0  The city is building a new reservoir, fixing t...    (33.749, -84.388)
# 1                                                NaN  (30.2672, -97.7431)
# 2                                                NaN  (30.2672, -97.7431)
# 3                                                NaN  (30.2672, -97.7431)
# 4                                                NaN  (30.2672, -97.7431)

# %%
cwr.head()
# Out:
#    Account No             Organisation       City                   Country  \
# 0        1093          City of Atlanta    Atlanta  United States of America
# 1        1093          City of Atlanta    Atlanta  United States of America
# 2        1184           City of Austin     Austin  United States of America
# 3        1499  Ajuntament de Barcelona  Barcelona                     Spain
# 4        1499  Ajuntament de Barcelona  Barcelona                     Spain
#
#           Region  Access  C40  Reporting year  \
# 0  North America  public  NaN            2018
# 1  North America  public  NaN            2018
# 2  North America  public  C40            2018
# 3         Europe  public  C40            2018
# 4         Europe  public  C40            2018
#
#          Risks to city's water supply    Timescale          Magnitude  \
# 0  Increased water stress or scarcity   Short-term            Serious
# 1                 Higher water prices      Current            Serious
# 2  Increased water stress or scarcity  Medium-term  Extremely serious
# 3  Increased water stress or scarcity      Current  Extremely serious
# 4             Declining water quality  Medium-term            Serious
#
#                                     Risk description  Current population  \
# 0  The city depends on one river for water supply...            450182.0
# 1  The water cost burden is felt across all ZIP c...            450182.0
# 2                                                NaN           1265974.0
# 3  The downscaling of the climate projections at ...           1604555.0
# 4  A reduction in water resources availability  c...           1604555.0
#
#    Population year        City Location
# 0             2017    (33.749, -84.388)
# 1             2017    (33.749, -84.388)
# 2             2017  (30.2672, -97.7431)
# 3             2015    (41.3823, 2.1775)
# 4             2015    (41.3823, 2.1775)

# %% [markdown]
# ## Normalize columns names

# %%
# Convert columns names to lowercase
cwa.columns = cwa.columns.str.lower().str.replace(" ", "_").str.replace("'","")
cwr.columns = cwr.columns.str.lower().str.replace(" ", "_").str.replace("'","")

# %% [markdown]
# ## Find counts of nulls per column

# %%
cwr.isnull().sum()
# Out:
# account_no                       0
# organisation                     0
# city                             0
# country                          0
# region                           0
# access                           0
# c40                            504
# reporting_year                   0
# risks_to_citys_water_supply     40
# timescale                       11
# magnitude                      159
# risk_description               107
# current_population               0
# population_year                  0
# city_location                    0
# dtype: int64

# %%
cwa.isnull().sum()
# Out:
# account_no                       0
# organisation                     0
# city                             0
# country                          0
# region                           0
# access                           0
# c40                            536
# reporting_year                   0
# risks_to_citys_water_supply     75
# adaptation_action               19
# action_description             146
# city_location                    0
# dtype: int64

# %% [markdown]
# ## Find columns that exist in both datasets

# %%
id_columns = list(set(cwr.columns) & set(cwa.columns))
id_columns
# Out:
# ['region',
#  'city',
#  'country',
#  'c40',
#  'access',
#  'reporting_year',
#  'risks_to_citys_water_supply',
#  'account_no',
#  'city_location',
#  'organisation']

# %% [markdown]
# ## Check how many nulls exist in these columns

# %%
cwr[id_columns].isnull().sum()
# Out:
# region                           0
# city                             0
# country                          0
# c40                            504
# access                           0
# reporting_year                   0
# risks_to_citys_water_supply     40
# account_no                       0
# city_location                    0
# organisation                     0
# dtype: int64

# %%
cwa[id_columns].isnull().sum()
# Out:
# region                           0
# city                             0
# country                          0
# c40                            536
# access                           0
# reporting_year                   0
# risks_to_citys_water_supply     75
# account_no                       0
# city_location                    0
# organisation                     0
# dtype: int64

# %% [markdown]
# ## Replace nulls there with "nan" strings, so that merging is done correctly

# %%
cwr['c40'] = cwr['c40'] == 'C40'
cwr[id_columns] = cwr[id_columns].fillna('nan')

# %%
cwa['c40'] = cwa['c40'] == 'C40'
cwa[id_columns] = cwa[id_columns].fillna('nan')

# %% [markdown]
# ## Check id_columns uniqueness

# %%
len(cwa[id_columns]), len(cwa[id_columns].drop_duplicates())
# Out:
# (685, 484)

# %%
len(cwr[id_columns]), len(cwr[id_columns].drop_duplicates())
# Out:
# (608, 578)

# %% [markdown]
# ## Aggregate by grouping by id_columns and applying set operations to other colums

# %%
cwa_agg = cwa.groupby(id_columns).agg(set).reset_index()
cwr_agg = cwr.groupby(id_columns).agg(set).reset_index()

# %% [markdown]
# ## Make sure that risks magnitude (which is going to be used as an entry label) has a single value

# %%
cwr_agg.magnitude = cwr_agg.magnitude.apply(lambda x: 'Extremely serious' if 'Extremely serious' in x  else ('Serious' if 'Serious' in x else list(x)[0]))

# %%
cwr_agg.magnitude.unique()
# Out:
# array([nan, 'Serious', 'Extremely serious', 'Less Serious'], dtype=object)

# %% [markdown]
# ## Merge (outer) datasets and find the columns that are set (list_columns)
# filling the non-merged rows with {np.nan} on list_columns to make sure there is contingency in each column

# %%
cw_data = pd.merge(cwa_agg, cwr_agg, on=id_columns, how='outer')
list_columns = cw_data.iloc[0].apply(lambda x: isinstance(x, set))
list_columns = list_columns[list_columns].index
cw_data[list_columns] = cw_data[list_columns].applymap(lambda x: {np.nan} if pd.isna(x) else x)

# %%
cw_data.head()
# Out:
#    region       city         country    c40  access  reporting_year  \
# 0  Africa      Abuja         Nigeria  False  public            2018
# 1  Africa      Abuja         Nigeria  False  public            2018
# 2  Africa      Abuja         Nigeria  False  public            2018
# 3  Africa    BouakÃ©  CÃ´te d'Ivoire  False  public            2018
# 4  Africa  Cape Town    South Africa   True  public            2018
#
#           risks_to_citys_water_supply  account_no        city_location  \
# 0                 Higher water prices       36043   (9.07647, 7.39857)
# 1  Inadequate or aging infrastructure       36043   (9.07647, 7.39857)
# 2  Increased water stress or scarcity       36043   (9.07647, 7.39857)
# 3             Declining water quality      831617    (7.4137, -5.0149)
# 4  Increased water stress or scarcity       35858  (-33.9253, 18.4239)
#
#                       organisation  \
# 0  Abuja Federal Capital Territory
# 1  Abuja Federal Capital Territory
# 2  Abuja Federal Capital Territory
# 3               Commune de BouakÃ©
# 4                City of Cape Town
#
#                                    adaptation_action  \
# 0                                   {Water metering}
# 1  {Investment in existing water supply infrastru...
# 2              {Efficiency regulations or standards}
# 3  {Diversifying water supply (including new sour...
# 4  {Water metering, Use of non-potable water outs...
#
#                                   action_description     timescale  \
# 0                                              {nan}  {Short-term}
# 1                                              {nan}         {nan}
# 2                                              {nan}  {Short-term}
# 3  {Approvisionnement en eau potable par la const...     {Current}
# 4  {In terms of diversifying water supply (includ...     {Current}
#
#            magnitude                                   risk_description  \
# 0                NaN                                              {nan}
# 1                NaN                                              {nan}
# 2                NaN                                              {nan}
# 3  Extremely serious      {La ville manque d'eau depuis plus de 5 mois}
# 4  Extremely serious  {The City has generally been able to successfu...
#
#   current_population population_year
# 0        {2440000.0}          {2017}
# 1              {nan}           {nan}
# 2        {2440000.0}          {2017}
# 3         {715435.0}          {2013}
# 4        {4174510.0}          {2017}

# %% [markdown]
# ## Extract longitude and latitude from city_location

# %%
cw_data['city_location'] = cw_data['city_location'].apply(eval)
cw_data['latitude'] = cw_data['city_location'].apply(lambda x: x[0])
cw_data['longitude'] = cw_data['city_location'].apply(lambda x: x[1])
id_columns = [x for x in id_columns] + ['latitude','longitude']

# %% [markdown]
# ## Find list columns that are singular (every element contains a length 1 list)

# %%
cw_value_columns = [ x for x in cw_data.columns if x not in id_columns]
# Values that can be converted back to strings from sets

singular_cols = cw_data.set_index(id_columns)[list_columns].applymap(lambda x: len(x)==1).product() > 0
singular_cols
# Out:
# adaptation_action     False
# action_description    False
# timescale             False
# risk_description      False
# current_population     True
# population_year        True
# dtype: bool

# %% [markdown]
# ## Convert singular columns to non list ones

# %%
# magnitude is nicely singular per id
cw_data.loc[:, singular_cols[singular_cols].index] = cw_data.loc[:, singular_cols[singular_cols].index].applymap(lambda x: list(x)[0])
list_columns = [x for x in list_columns if x not in singular_cols[singular_cols].index]

# %% [markdown]
# ## Remove entries that are invalid or in different language than English from the list columns
# **also convert sets to lists**

# %%
def try_lang_detect_except(x):
    try:
        return (langdetect(x)=='en')
    except:
        return False
cw_data = cw_data.applymap(lambda x: [t for t in x if not pd.isnull(t)  and  (t!='') and (t!='ERROR: #NAME?') and try_lang_detect_except(t)] if isinstance(x,set) else x)

# %% [markdown]
# ## Fix specific risks annotations by inspection

# %%
cw_data.risks_to_citys_water_supply.unique()
# Out:
# array(['Higher water prices', 'Inadequate or aging infrastructure',
#        'Increased water stress or scarcity', 'Declining water quality',
#        'nan', 'Increased water demand', 'Regulatory',
#        'Energy supply issues', 'Inadequate or ageing infrastructure',
#        'Declining water quality: Declining water quality'], dtype=object)

# %%
cw_data.risks_to_citys_water_supply = cw_data.risks_to_citys_water_supply.apply(lambda x: x.replace('Inadequate or ageing infrastructure','Inadequate or aging infrastructure'))
cw_data['risks_to_citys_water_supply'] = cw_data['risks_to_citys_water_supply'].apply(lambda x: x.replace('Declining water quality: Declining water quality', 'Declining water quality'))
cw_data.risks_to_citys_water_supply.unique()
# Out:
# array(['Higher water prices', 'Inadequate or aging infrastructure',
#        'Increased water stress or scarcity', 'Declining water quality',
#        'nan', 'Increased water demand', 'Regulatory',
#        'Energy supply issues'], dtype=object)

# %%
cw_data.head()
# Out:
#    region       city         country    c40  access  reporting_year  \
# 0  Africa      Abuja         Nigeria  False  public            2018
# 1  Africa      Abuja         Nigeria  False  public            2018
# 2  Africa      Abuja         Nigeria  False  public            2018
# 3  Africa    BouakÃ©  CÃ´te d'Ivoire  False  public            2018
# 4  Africa  Cape Town    South Africa   True  public            2018
#
#           risks_to_citys_water_supply  account_no        city_location  \
# 0                 Higher water prices       36043   (9.07647, 7.39857)
# 1  Inadequate or aging infrastructure       36043   (9.07647, 7.39857)
# 2  Increased water stress or scarcity       36043   (9.07647, 7.39857)
# 3             Declining water quality      831617    (7.4137, -5.0149)
# 4  Increased water stress or scarcity       35858  (-33.9253, 18.4239)
#
#                       organisation  \
# 0  Abuja Federal Capital Territory
# 1  Abuja Federal Capital Territory
# 2  Abuja Federal Capital Territory
# 3               Commune de BouakÃ©
# 4                City of Cape Town
#
#                                    adaptation_action  \
# 0                                                 []
# 1  [Investment in existing water supply infrastru...
# 2              [Efficiency regulations or standards]
# 3  [Diversifying water supply (including new sour...
# 4  [Use of non-potable water outside, Stormwater ...
#
#                                   action_description     timescale  \
# 0                                                 []  [Short-term]
# 1                                                 []            []
# 2                                                 []  [Short-term]
# 3                                                 []            []
# 4  [In terms of diversifying water supply (includ...            []
#
#            magnitude                                   risk_description  \
# 0                NaN                                                 []
# 1                NaN                                                 []
# 2                NaN                                                 []
# 3  Extremely serious                                                 []
# 4  Extremely serious  [The City has generally been able to successfu...
#
#    current_population  population_year  latitude  longitude
# 0           2440000.0           2017.0   9.07647    7.39857
# 1                 NaN              NaN   9.07647    7.39857
# 2           2440000.0           2017.0   9.07647    7.39857
# 3            715435.0           2013.0   7.41370   -5.01490
# 4           4174510.0           2017.0 -33.92530   18.42390

# %% [markdown]
# ## Drop metadata columns that will not be used

# %%
to_drop = ['timescale','current_population','population_year']
cw_data.drop(columns=['timescale','current_population','population_year'],inplace=True)

# %% [markdown]
# ## Generate for each of the  list columns a new one that contains the number of elements
# **Create value_columns that contains the names of all the list columns + the created ones**

# %%
value_columns = set([x for x in cw_value_columns if x not in to_drop] + ['risks_to_citys_water_supply'])
list_columns = cw_data.iloc[0].apply(lambda x: isinstance(x, list))
list_columns = list_columns[list_columns].index
len_columns = set()
for x in value_columns.copy():
    if x in list_columns:
        cw_data[x+'_n'] = cw_data[x].apply(lambda x: len(x) if x else 1)
        len_columns.add(x+'_n')
value_columns = value_columns.union(len_columns)
value_columns
# Out:
# {'action_description',
#  'action_description_n',
#  'adaptation_action',
#  'adaptation_action_n',
#  'magnitude',
#  'risk_description',
#  'risk_description_n',
#  'risks_to_citys_water_supply'}

# %% [markdown]
# # Filter by C40
# **We are making the assumption that, given that those cities participate in a specific program, they will also have better structured data. So this subset will be used as a reference for the imputation**

# %%
c40_data = cw_data[cw_data['c40']].copy()
c40_data.shape
# Out:
# (112, 19)

# %% [markdown]
# ## Find the null percentage of list columns

# %%
list_nulls = c40_data[list_columns].applymap(lambda x: len(x) == 0)
list_nulls.mean()
# Out:
# adaptation_action     0.366071
# action_description    0.464286
# risk_description      0.366071
# dtype: float64

# %%
c40_data['magnitude'].unique()
# Out:
# array(['Extremely serious', nan, 'Serious', 'Less Serious'], dtype=object)

# %% [markdown]
# ## Create a report of the values of magnitude

# %%
c40_risks = c40_data[id_columns+['magnitude']].copy()
c40_risks['low'] = c40_risks['magnitude'] == 'Less Serious'
c40_risks['medium'] = c40_risks['magnitude'] == 'Serious'
c40_risks['high'] = c40_risks['magnitude'] == 'Extremely serious'
c40_risks['unknown'] = c40_risks['magnitude'].isna()
c40_risks = c40_risks.drop(columns=['magnitude']).groupby([x for x in id_columns if x!="risks_to_citys_water_supply"]).agg(sum).reset_index()
c40_risks
# Out:
#                         region               city  \
# 0                       Africa        Addis Ababa
# 1                       Africa          Cape Town
# 2                       Africa      Dar es Salaam
# 3                       Africa             Durban
# 4                       Africa       Johannesburg
# 5                       Africa              Lagos
# 6                       Africa            Nairobi
# 7                    East Asia           Changwon
# 8                    East Asia             Dalian
# 9                    East Asia          Hong Kong
# 10                   East Asia              Tokyo
# 11                   East Asia           Yokohama
# 12                      Europe          Barcelona
# 13                      Europe             London
# 14                      Europe               Oslo
# 15                      Europe              Paris
# 16                      Europe               Roma
# 17                      Europe          Stockholm
# 18                      Europe             Warsaw
# 19               Latin America           Curitiba
# 20               Latin America        Guadalajara
# 21               Latin America          MedellÃ­n
# 22               Latin America        Mexico City
# 23               Latin America              Quito
# 24               Latin America     Rio de Janeiro
# 25               Latin America           Santiago
# 26               Latin America         SÃ£o Paulo
# 27                 Middle East              Amman
# 28               North America             Austin
# 29               North America       Portland, OR
# 30               North America      San Francisco
# 31               North America            Seattle
# 32               North America          Vancouver
# 33               North America     Washington, DC
# 34         South and West Asia              Dhaka
# 35         South and West Asia            Karachi
# 36         South and West Asia            Kolkata
# 37  Southeast Asia and Oceania           Auckland
# 38  Southeast Asia and Oceania            Bangkok
# 39  Southeast Asia and Oceania  City of Melbourne
# 40  Southeast Asia and Oceania     City of Sydney
# 41  Southeast Asia and Oceania        Ho Chi Minh
# 42  Southeast Asia and Oceania            Jakarta
#
#                                               country   c40  access  \
# 0                                            Ethiopia  True  public
# 1                                        South Africa  True  public
# 2                         United Republic of Tanzania  True  public
# 3                                        South Africa  True  public
# 4                                        South Africa  True  public
# 5                                             Nigeria  True  public
# 6                                               Kenya  True  public
# 7                                   Republic of Korea  True  public
# 8                                               China  True  public
# 9      China, Hong Kong Special Administrative Region  True  public
# 10                                              Japan  True  public
# 11                                              Japan  True  public
# 12                                              Spain  True  public
# 13  United Kingdom of Great Britain and Northern I...  True  public
# 14                                             Norway  True  public
# 15                                             France  True  public
# 16                                              Italy  True  public
# 17                                             Sweden  True  public
# 18                                             Poland  True  public
# 19                                             Brazil  True  public
# 20                                             Mexico  True  public
# 21                                           Colombia  True  public
# 22                                             Mexico  True  public
# 23                                            Ecuador  True  public
# 24                                             Brazil  True  public
# 25                                              Chile  True  public
# 26                                             Brazil  True  public
# 27                                             Jordan  True  public
# 28                           United States of America  True  public
# 29                           United States of America  True  public
# 30                           United States of America  True  public
# 31                           United States of America  True  public
# 32                                             Canada  True  public
# 33                           United States of America  True  public
# 34                                         Bangladesh  True  public
# 35                                           Pakistan  True  public
# 36                                              India  True  public
# 37                                        New Zealand  True  public
# 38                                           Thailand  True  public
# 39                                          Australia  True  public
# 40                                          Australia  True  public
# 41                                           Viet Nam  True  public
# 42                                          Indonesia  True  public
#
#     reporting_year  account_no         city_location  \
# 0             2018       31146    (9.02887, 38.7544)
# 1             2018       35858   (-33.9253, 18.4239)
# 2             2018       35893   (-6.79235, 39.2083)
# 3             2018       35863   (-29.8587, 31.0218)
# 4             2018       31115   (-26.2041, 28.0473)
# 5             2018       31167     (6.52437, 3.3792)
# 6             2018       35913   (-1.29206, 36.8219)
# 7             2018       31186    (35.1542, 126.949)
# 8             2018       54298    (38.9389, 121.567)
# 9             2018       31169     (22.2881, 114.14)
# 10            2018       31111       (35.41, 139.41)
# 11            2018       31113    (35.4437, 139.638)
# 12            2018        1499     (41.3823, 2.1775)
# 13            2018        3422   (51.5048, -0.07868)
# 14            2018       14088    (59.9139, 10.7522)
# 15            2018       31175    (48.8566, 2.35222)
# 16            2018       31110      (41.53, 12.2858)
# 17            2018        3429    (59.3293, 18.0686)
# 18            2018       31185    (52.2297, 21.0122)
# 19            2018       31156  (-25.4311, -49.2647)
# 20            2018       35867    (20.6597, -103.35)
# 21            2018       35873   (6.22729, -75.5735)
# 22            2018       31172   (19.4326, -99.1332)
# 23            2018       42178   (-0.2333, -78.5167)
# 24            2018       31176  (-22.9054, -43.5614)
# 25            2018       31180  (-33.4489, -70.6693)
# 26            2018       31184  (-23.5595, -46.7382)
# 27            2018       54337    (31.9454, 35.9284)
# 28            2018        1184   (30.2672, -97.7431)
# 29            2018       14874     (45.52, -122.682)
# 30            2018       31182   (37.7749, -122.419)
# 31            2018       16581   (47.6062, -122.332)
# 32            2018       20113   (49.2612, -123.114)
# 33            2018       31090   (38.9072, -77.0369)
# 34            2018       50782    (23.8103, 90.4125)
# 35            2018       31168    (24.9108, 67.1281)
# 36            2018       35904    (22.5726, 88.3639)
# 37            2018       43932   (-36.8153, 174.742)
# 38            2018       31150    (13.7712, 100.556)
# 39            2018       31109   (-37.8141, 144.963)
# 40            2018       31114   (-33.8675, 151.207)
# 41            2018       31164     (10.7626, 106.66)
# 42            2018       31166    (-6.1751, 106.865)
#
#                                          organisation  latitude  longitude  \
# 0                     Addis Ababa City Administration   9.02887   38.75440
# 1                                   City of Cape Town -33.92530   18.42390
# 2                               City of Dar es Salaam  -6.79235   39.20830
# 3                                      City of Durban -29.85870   31.02180
# 4                                City of Johannesburg -26.20410   28.04730
# 5                                       City of Lagos   6.52437    3.37920
# 6                                     City of Nairobi  -1.29206   36.82190
# 7                                       Changwon City  35.15420  126.94900
# 8                Dalian Municipal People's Government  38.93890  121.56700
# 9   Government of Hong Kong Special Administrative...  22.28810  114.14000
# 10                      Tokyo Metropolitan Government  35.41000  139.41000
# 11                                   City of Yokohama  35.44370  139.63800
# 12                            Ajuntament de Barcelona  41.38230    2.17750
# 13                           Greater London Authority  51.50480   -0.07868
# 14                                       City of Oslo  59.91390   10.75220
# 15                                      City of Paris  48.85660    2.35222
# 16                                      Roma Capitale  41.53000   12.28580
# 17                                  City of Stockholm  59.32930   18.06860
# 18                                     City of Warsaw  52.22970   21.01220
# 19                           Municipality of Curitiba -25.43110  -49.26470
# 20                Region Metropolitana de Guadalajara  20.65970 -103.35000
# 21                          Municipality of MedellÃ­n   6.22729  -75.57350
# 22                                        Mexico City  19.43260  -99.13320
# 23                    Distrito Metropolitano de Quito  -0.23330  -78.51670
# 24                       Prefeitura do Rio de Janeiro -22.90540  -43.56140
# 25                  RegiÃ³n Metropolitana de Santiago -33.44890  -70.66930
# 26                           Prefeitura de SÃ£o Paulo -23.55950  -46.73820
# 27                         Greater Amman Municipality  31.94540   35.92840
# 28                                     City of Austin  30.26720  -97.74310
# 29                               City of Portland, OR  45.52000 -122.68200
# 30                              City of San Francisco  37.77490 -122.41900
# 31                                    City of Seattle  47.60620 -122.33200
# 32                                  City of Vancouver  49.26120 -123.11400
# 33                               District of Columbia  38.90720  -77.03690
# 34                                         Dhaka City  23.81030   90.41250
# 35                   City District Government Karachi  24.91080   67.12810
# 36                          Kolkata Metropolitan Area  22.57260   88.36390
# 37                                   Auckland Council -36.81530  174.74200
# 38                Bangkok Metropolitan Administration  13.77120  100.55600
# 39                                  City of Melbourne -37.81410  144.96300
# 40                                     City of Sydney -33.86750  151.20700
# 41                                   Ho Chi Minh City  10.76260  106.66000
# 42                            Jakarta City Government  -6.17510  106.86500
#
#     low  medium  high  unknown
# 0     0       3     0        0
# 1     0       0     1        0
# 2     0       2     0        1
# 3     0       0     0        2
# 4     0       0     0        1
# 5     0       5     2        1
# 6     0       2     0        0
# 7     0       1     0        0
# 8     0       0     0        2
# 9     1       1     0        1
# 10    0       4     0        1
# 11    0       1     0        0
# 12    0       3     1        1
# 13    1       2     0        0
# 14    1       0     1        1
# 15    0       0     0        2
# 16    0       0     2        1
# 17    1       1     0        0
# 18    0       1     0        0
# 19    1       0     0        0
# 20    0       0     0        1
# 21    0       2     0        0
# 22    0       0     2        1
# 23    0       1     0        0
# 24    0       2     1        1
# 25    0       3     0        0
# 26    0       1     0        0
# 27    0       0     2        0
# 28    0       0     1        0
# 29    0       0     0        5
# 30    0       1     0        0
# 31    0       0     0        1
# 32    1       0     0        0
# 33    0       3     0        1
# 34    0       0     0        5
# 35    0       0     1        0
# 36    0       0     0        1
# 37    0       3     0        1
# 38    1       0     0        0
# 39    0       2     0        0
# 40    0       5     0        1
# 41    3       1     0        0
# 42    0       0     0        6

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from utils.nlp import SimilarityAnalysis, create_sim_vector

# %%
c40_data.risks_to_citys_water_supply = c40_data.risks_to_citys_water_supply.apply(lambda x: np.nan if x=='nan' else x)

# %%
c40_data[c40_data.risks_to_citys_water_supply.isnull()]
# Out:
#                          region          city                   country   c40  \
# 21                       Africa  Johannesburg              South Africa  True
# 71                    East Asia         Tokyo                     Japan  True
# 108                      Europe          Oslo                    Norway  True
# 404               North America  Portland, OR  United States of America  True
# 454         South and West Asia         Dhaka                Bangladesh  True
# 456         South and West Asia       Kolkata                     India  True
# 476  Southeast Asia and Oceania       Jakarta                 Indonesia  True
#
#      access  reporting_year risks_to_citys_water_supply  account_no  \
# 21   public            2018                         NaN       31115
# 71   public            2018                         NaN       31111
# 108  public            2018                         NaN       14088
# 404  public            2018                         NaN       14874
# 454  public            2018                         NaN       50782
# 456  public            2018                         NaN       35904
# 476  public            2018                         NaN       31166
#
#            city_location                   organisation  \
# 21   (-26.2041, 28.0473)           City of Johannesburg
# 71       (35.41, 139.41)  Tokyo Metropolitan Government
# 108   (59.9139, 10.7522)                   City of Oslo
# 404    (45.52, -122.682)           City of Portland, OR
# 454   (23.8103, 90.4125)                     Dhaka City
# 456   (22.5726, 88.3639)      Kolkata Metropolitan Area
# 476   (-6.1751, 106.865)        Jakarta City Government
#
#                                      adaptation_action  \
# 21                            [Water use restrictions]
# 71                                                  []
# 108  [Stormwater management (natural or man-made in...
# 404                           [Watershed preservation]
# 454  [Stormwater management (natural or man-made in...
# 456  [Stormwater management (natural or man-made in...
# 476  [Other: Stormwater management (natural or man ...
#
#                                     action_description magnitude  \
# 21   [A by-law that effects water restrictions is i...       NaN
# 71               [Implementing measures against flood]   Serious
# 108  [High activity on re-opening urban rivers and ...       NaN
# 404  [Portland seeks to manage the watershed in way...       NaN
# 454  [Embankment is constructed around Dhaka City t...       NaN
# 456  [Channelisation of drains Construction of new ...       NaN
# 476  [- Restore damaged and lost water ecosystems (...       NaN
#
#                                       risk_description  latitude  longitude  \
# 21                                                  []  -26.2041    28.0473
# 71                                                  []   35.4100   139.4100
# 108                                                 []   59.9139    10.7522
# 404  [Portland has a secondary, redundant, groundwa...   45.5200  -122.6820
# 454                    [Increases water born diseases]   23.8103    90.4125
# 456  [Kolkata is currently ranked as the third most...   22.5726    88.3639
# 476  [Increased frequency of rain affecting the are...   -6.1751   106.8650
#
#      risk_description_n  action_description_n  adaptation_action_n
# 21                    1                     1                    1
# 71                    1                     1                    1
# 108                   1                     4                    3
# 404                   1                     1                    1
# 454                   1                     1                    1
# 456                   2                     2                    2
# 476                   1                     1                    1

# %%
c40_data.risks_to_citys_water_supply.unique()
# Out:
# array(['Increased water stress or scarcity',
#        'Inadequate or aging infrastructure', nan,
#        'Declining water quality', 'Energy supply issues',
#        'Higher water prices', 'Increased water demand', 'Regulatory'],
#       dtype=object)

# %% [markdown]
# ## Fit Similarity Analysis
# **per string list column of the value columns, by concatenating strings together. Vectorize all the string list columns based on their in between similarities**

# %%
analyses = {x:SimilarityAnalysis() for x in value_columns if x in list_columns}

# %%
vectorized = np.hstack([analyses[x].fit_transform(c40_data[x]) for x in analyses])

# %% [markdown]
# ## Encode magnitude and risks into numerical labels

# %%
cols_to_encode =  [x for x in value_columns if x not in list_columns and x not in len_columns]
c40_data[cols_to_encode] = c40_data[cols_to_encode].fillna('nan')
encoders = {x:LabelEncoder().fit(c40_data[x].fillna('nan')) for x in cols_to_encode}

# %%
encoded = np.array([encoders[x].transform(c40_data[x]) for x in encoders]).T.astype(float)
for t in range(len(cols_to_encode)):
    encoded[encoded[:,t] == np.where(encoders[cols_to_encode[t]].classes_=='nan')[0]] = np.nan

# %%
lab_freqs = c40_data[cols_to_encode].groupby(cols_to_encode,as_index=False).size()
lab_freqs
# Out:
#            risks_to_citys_water_supply          magnitude  size
# 0              Declining water quality       Less Serious     2
# 1              Declining water quality            Serious     9
# 2              Declining water quality                nan     3
# 3                 Energy supply issues  Extremely serious     1
# 4                 Energy supply issues            Serious     1
# 5                  Higher water prices  Extremely serious     1
# 6                  Higher water prices       Less Serious     1
# 7                  Higher water prices            Serious     1
# 8                  Higher water prices                nan     3
# 9   Inadequate or aging infrastructure  Extremely serious     3
# 10  Inadequate or aging infrastructure       Less Serious     2
# 11  Inadequate or aging infrastructure            Serious     8
# 12  Inadequate or aging infrastructure                nan    19
# 13              Increased water demand  Extremely serious     1
# 14              Increased water demand       Less Serious     1
# 15              Increased water demand            Serious     6
# 16  Increased water stress or scarcity  Extremely serious     8
# 17  Increased water stress or scarcity       Less Serious     3
# 18  Increased water stress or scarcity            Serious    21
# 19  Increased water stress or scarcity                nan     6
# 20                          Regulatory       Less Serious     1
# 21                          Regulatory            Serious     3
# 22                          Regulatory                nan     1
# 23                                 nan            Serious     1
# 24                                 nan                nan     6

# %% [markdown]
# ## Create dataset that contains the encoded labels, the vectorized columns and the columns referring the lists lengths

# %%
whole = np.hstack([encoded, vectorized, c40_data[len_columns]])

# %%
import sys
sys.path.append('..')
from labeled_preprocessing.imputation import LabeledDatasetImputer

# %% [markdown]
# ## Fit LabeledDatasetImputer and transform dataset
# **(LabeledDatasetImputer is a union of two Iterative Imputers , one for labels and one for features)**

# %%
imputer = LabeledDatasetImputer(verbose=2,k_features_per_label=0, seed=seed)
continuous_imputed, y = imputer.fit_transform(whole[:,2:], whole[:,:2], ret_imputed_x=True)
# Out:
# Applying feature selection..
# Creating imputed X using KNeighborsRegressor..
# [IterativeImputer] Completing matrix with shape (112, 205)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 2.14
# [IterativeImputer] Change: 17.38138431632505, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 2/10, elapsed time 3.75
# [IterativeImputer] Change: 11.920637652295014, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 3/10, elapsed time 5.19
# [IterativeImputer] Change: 3.104392637558429, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 4/10, elapsed time 6.63
# [IterativeImputer] Change: 0.8415462663279819, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 5/10, elapsed time 8.02
# [IterativeImputer] Change: 0.9440332167247709, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 6/10, elapsed time 9.50
# [IterativeImputer] Change: 1.2595935187934937, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 7/10, elapsed time 11.10
# [IterativeImputer] Change: 0.6487446644046828, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 8/10, elapsed time 12.78
# [IterativeImputer] Change: 0.3006072565879008, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 9/10, elapsed time 14.27
# [IterativeImputer] Change: 0.27537189964454567, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 10/10, elapsed time 15.94
# [IterativeImputer] Change: 0.48316144663168503, scaled tolerance: 0.011
# Creating imputed Y using Pipeline..
# [IterativeImputer] Completing matrix with shape (112, 207)
# /home/vaslem/code/Modern Data Analytics/.venv/lib/python3.8/site-packages/sklearn/impute/_iterative.py:685: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.26
# [IterativeImputer] Change: 5.0, scaled tolerance: 0.011
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.47
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.011
# [IterativeImputer] Early stopping criterion reached.

# %% [markdown]
# ## Use the prediction power on the imputed data as measurement of coherent imputation.

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
simple_model = make_pipeline(StandardScaler(), SVC(kernel='linear', C=0.01, random_state=seed))
scoring = 'accuracy' 
scores = cross_val_score(simple_model, continuous_imputed, y[:,cols_to_encode.index('magnitude')], cv=5,scoring=scoring)
np.mean(scores)
# Out:
# 0.7411067193675889

# %% [markdown]
# ## Plot features correlation

# %%
import matplotlib.pyplot as plt
flg = np.all(~np.isnan(whole),axis=1), np.hstack([[True, True], imputer.selection_mask[:]])
corr = np.corrcoef(whole[flg[0],:][:,flg[1]].T)
print(corr.shape)
plt.matshow(corr)
# Out:
# (207, 207)

# %% [markdown]
# ## Retrieve the categorical imputed labels

# %%
imputed = np.array([
    encoders[x].inverse_transform(
    y[:, c].astype(int)
 ) for c,x in enumerate(cols_to_encode)]).T

# %%
c40_data_imputed = c40_data.copy()

# %%
c40_data_imputed[cols_to_encode] = imputed

# %%
c40_data_imputed.head()
# Out:
#     region           city                      country   c40  access  \
# 4   Africa      Cape Town                 South Africa  True  public
# 7   Africa  Dar es Salaam  United Republic of Tanzania  True  public
# 8   Africa         Durban                 South Africa  True  public
# 21  Africa   Johannesburg                 South Africa  True  public
# 24  Africa          Lagos                      Nigeria  True  public
#
#     reporting_year         risks_to_citys_water_supply  account_no  \
# 4             2018  Increased water stress or scarcity       35858
# 7             2018  Increased water stress or scarcity       35893
# 8             2018  Increased water stress or scarcity       35863
# 21            2018  Increased water stress or scarcity       31115
# 24            2018             Declining water quality       31167
#
#           city_location           organisation  \
# 4   (-33.9253, 18.4239)      City of Cape Town
# 7   (-6.79235, 39.2083)  City of Dar es Salaam
# 8   (-29.8587, 31.0218)         City of Durban
# 21  (-26.2041, 28.0473)   City of Johannesburg
# 24    (6.52437, 3.3792)          City of Lagos
#
#                                     adaptation_action  \
# 4   [Use of non-potable water outside, Stormwater ...
# 7   [Investment in existing water supply infrastru...
# 8   [Watershed preservation, Investment in existin...
# 21                           [Water use restrictions]
# 24                           [Water use restrictions]
#
#                                    action_description          magnitude  \
# 4   [In terms of diversifying water supply (includ...  Extremely serious
# 7   [City provide some % of the total money correc...            Serious
# 8   [A number of innovative approaches have been p...            Serious
# 21  [A by-law that effects water restrictions is i...            Serious
# 24  [Application of water abstraction rules, surch...            Serious
#
#                                      risk_description  latitude  longitude  \
# 4   [The City has generally been able to successfu... -33.92530    18.4239
# 7                                                  []  -6.79235    39.2083
# 8                                                  [] -29.85870    31.0218
# 21                                                 [] -26.20410    28.0473
# 24  [Increased rainfall will result to greater amo...   6.52437     3.3792
#
#     risk_description_n  action_description_n  adaptation_action_n
# 4                    1                    10                    9
# 7                    1                     1                    1
# 8                    1                     3                    3
# 21                   1                     1                    1
# 24                   1                     1                    1

# %% [markdown]
# ## Find which labels  have been updated after imputation

# %%
imp_lab_freqs = c40_data_imputed[cols_to_encode].groupby(cols_to_encode,as_index=False).size()
imp_ret = pd.merge(lab_freqs, imp_lab_freqs,suffixes=('','_imp'), how='right',on=cols_to_encode)
imp_ret['increase'] = (imp_ret['size_imp'] - imp_ret['size'])/imp_ret['size']
imp_ret
# Out:
#            risks_to_citys_water_supply          magnitude  size  size_imp  \
# 0              Declining water quality       Less Serious     2         2
# 1              Declining water quality            Serious     9        16
# 2                 Energy supply issues  Extremely serious     1         1
# 3                 Energy supply issues            Serious     1         1
# 4                  Higher water prices  Extremely serious     1         1
# 5                  Higher water prices       Less Serious     1         1
# 6                  Higher water prices            Serious     1         1
# 7   Inadequate or aging infrastructure  Extremely serious     3         3
# 8   Inadequate or aging infrastructure       Less Serious     2         2
# 9   Inadequate or aging infrastructure            Serious     8        17
# 10              Increased water demand  Extremely serious     1         1
# 11              Increased water demand       Less Serious     1         1
# 12              Increased water demand            Serious     6         6
# 13  Increased water stress or scarcity  Extremely serious     8        13
# 14  Increased water stress or scarcity       Less Serious     3         3
# 15  Increased water stress or scarcity            Serious    21        39
# 16                          Regulatory       Less Serious     1         1
# 17                          Regulatory            Serious     3         3
#
#     increase
# 0   0.000000
# 1   0.777778
# 2   0.000000
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   1.125000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.625000
# 14  0.000000
# 15  0.857143
# 16  0.000000
# 17  0.000000

# %% [markdown]
# ## Make sure that all risks have been encoded and are imputation outcome candidates

# %%
set([x for x in cw_data['risks_to_citys_water_supply'] if x not in encoders['risks_to_citys_water_supply'].classes_])
# Out:
# set()

# %% [markdown]
# # Impute whole dataset

# %%
cw_data['risks_to_citys_water_supply'].value_counts()
# Out:
# Increased water stress or scarcity    205
# Inadequate or aging infrastructure    180
# Declining water quality               127
# nan                                    54
# Increased water demand                 49
# Higher water prices                    38
# Regulatory                             17
# Energy supply issues                    7
# Name: risks_to_citys_water_supply, dtype: int64

# %% [markdown]
# ## Apply encoding and vectorization
# **based on fitted encoders and SimilarityAnalysis objects**

# %%
cw_data[cols_to_encode] = cw_data[cols_to_encode].fillna('nan')
encoded = np.array([encoders[x].transform(cw_data[x]) for x in encoders]).T.astype(float)
for t in range(len(cols_to_encode)):
    encoded[encoded[:,t] == np.where(encoders[cols_to_encode[t]].classes_=='nan')[0]] = np.nan

# %%
all_vectorized = np.hstack([analyses[x].transform(cw_data[x]) for x in value_columns if x in list_columns])

# %% [markdown]
# ## Apply imputation
# **using the trained imputer**

# %%
all_imputed_x, all_imputed_y  = imputer.transform(np.hstack([all_vectorized,cw_data[len_columns]]), encoded, ret_imputed_x=True)
# Out:
# [IterativeImputer] Completing matrix with shape (677, 205)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.84
# [IterativeImputer] Ending imputation round 2/10, elapsed time 3.52
# [IterativeImputer] Ending imputation round 3/10, elapsed time 5.33
# [IterativeImputer] Ending imputation round 4/10, elapsed time 7.02
# [IterativeImputer] Ending imputation round 5/10, elapsed time 8.64

# %%
all_imputed_y_dec = np.array([
    encoders[x].inverse_transform(
    all_imputed_y[:, c].astype(int)
 ) for c,x in enumerate(cols_to_encode)]).T

# %%
cw_data_imputed = cw_data.copy()
cw_data_imputed[cols_to_encode] = all_imputed_y_dec

# %% [markdown]
# ## Plot features correlation

# %%
import matplotlib.pyplot as plt
corr = np.corrcoef(np.hstack([all_imputed_y, all_imputed_x]).T)
print(corr.shape)
plt.matshow(corr)

# %%
scores = cross_val_score(simple_model, all_imputed_x, all_imputed_y[:,cols_to_encode.index('magnitude')], cv=5,scoring=scoring)
np.mean(scores)

# %% [markdown]
# **The score did not have significant drop, so we can assume that the imputation was cohesive across data**

# %% [markdown]
# ## Create output dataset

# %%
final_labeled_data = cw_data_imputed[['city','latitude','longitude','country','c40','region','magnitude','risks_to_citys_water_supply']].copy()
final_labeled_data.rename(columns={'magnitude': 'risk','risks_to_citys_water_supply': 'description'},inplace=True)
final_labeled_data.to_csv("../../data/labeled/processed.csv")

# %%
final_labeled_data

# %% [markdown]
# ## See a report of the filled labels

# %%
cw_lab_freqs = cw_data[cols_to_encode].groupby(cols_to_encode,as_index=False).size()
imp_cw_lab_freqs = cw_data_imputed[cols_to_encode].groupby(cols_to_encode,as_index=False).size()
imp_cw_ret = pd.merge(cw_lab_freqs, imp_cw_lab_freqs,suffixes=('','_imp'), how='right',on=cols_to_encode)
imp_cw_ret['increase'] = (imp_cw_ret['size_imp'] - imp_cw_ret['size'])/imp_cw_ret['size']
imp_cw_ret

# %%
pd.merge(imp_cw_ret, imp_ret, suffixes=('','_c40'), on=('magnitude','risks_to_citys_water_supply'))
