# %%
import pandas as pd 
import numpy as np
import json

# %%
with open("C:/Users/joach/code-projects/WaterSecurity/data/unlabeled/hdro2019.json") as jsonfile:
    json_hdro = json.load(jsonfile)

# %%
inicator_values = json_hdro['indicator_value']
country_name = json_hdro['country_name']
indicator_name = json_hdro['indicator_name']

# %%
df_inicator_values = pd.DataFrame(inicator_values).T
df_inicator_values.columns = [indicator_name[nm] for nm in df_inicator_values.columns]
df_inicator_values = df_inicator_values.applymap(lambda x: x['2019'] if pd.notnull(x) else x).head(50)
df_inicator_values.dropna(axis=1, how='all')
# Out:
#
# BHS                                                NaN
# BIH                                                NaN
# BLR                                                NaN
# BLZ                                                NaN
# BOL                                                NaN
# BRA                                                NaN
# BRB                                                NaN
# BRN                                                NaN
# BTN                                                NaN
# BWA                                                NaN
# CAF                                                NaN
# CAN                                                NaN
# CHL                                                NaN
# CHN                                                NaN
# CIV                                                NaN
# CMR                                                NaN
# COD                                                NaN
# COG                                                NaN
# COL                                                NaN
# COM                                                NaN
# CPV                                                NaN
# CRI                                                NaN
# CUB                                                NaN
# CYP                                                NaN
# CZE                                                NaN
# DEU                                                NaN
# DJI                                                NaN
# DMA                                                NaN
# DNK                                                NaN
# DOM                                                NaN
# DZA                                                NaN
# ECU                                                NaN
# EGY                                                NaN
#
#      Inequality among the poor  \
# AFG                        NaN
# AGO                        NaN
# ALB                        NaN
# AND                        NaN
# ARG                        NaN
# ARM                        NaN
# ATG                        NaN
# AUS                        NaN
# AUT                        NaN
# AZE                        NaN
# BDI                        NaN
# BEL                        NaN
# BEN                        NaN
# BFA                        NaN
# BGD                       0.01
# BGR                        NaN
# BHR                        NaN
# BHS                        NaN
# BIH                        NaN
# BLR                        NaN
# BLZ                        NaN
# BOL                        NaN
# BRA                        NaN
# BRB                        NaN
# BRN                        NaN
# BTN                        NaN
# BWA                        NaN
# CAF                        NaN
# CAN                        NaN
# CHL                        NaN
# CHN                        NaN
# CIV                        NaN
# CMR                        NaN
# COD                        NaN
# COG                        NaN
# COL                        NaN
# COM                        NaN
# CPV                        NaN
# CRI                        NaN
# CUB                        NaN
# CYP                        NaN
# CZE                        NaN
# DEU                        NaN
# DJI                        NaN
# DMA                        NaN
# DNK                        NaN
# DOM                        NaN
# DZA                        NaN
# ECU                        NaN
# EGY                        NaN
#
#      Proportion of births attended by skilled health personnel (%)  \
# AFG                                                NaN
# AGO                                                NaN
# ALB                                                NaN
# AND                                                NaN
# ARG                                                NaN
# ARM                                                NaN
# ATG                                                NaN
# AUS                                                NaN
# AUT                                                NaN
# AZE                                                NaN
# BDI                                                NaN
# BEL                                                NaN
# BEN                                                NaN
# BFA                                                NaN
# BGD                                                NaN
# BGR                                                NaN
# BHR                                                NaN
# BHS                                                NaN
# BIH                                                NaN
# BLR                                                NaN
# BLZ                                                NaN
# BOL                                                NaN
# BRA                                                NaN
# BRB                                                NaN
# BRN                                                NaN
# BTN                                                NaN
# BWA                                                NaN
# CAF                                                NaN
# CAN                                                NaN
# CHL                                                NaN
# CHN                                                NaN
# CIV                                                NaN
# CMR                                               69.0
# COD                                                NaN
# COG                                                NaN
# COL                                               99.1
# COM                                                NaN
# CPV                                                NaN
# CRI                                                NaN
# CUB                                                NaN
# CYP                                                NaN
# CZE                                                NaN
# DEU                                                NaN
# DJI                                                NaN
# DMA                                                NaN
# DNK                                                NaN
# DOM                                                NaN
# DZA                                                NaN
# ECU                                                NaN
# EGY                                                NaN
#
#      Gross enrolment ratio, primary (% of primary school-age population)  \
# AFG                                                NaN
# AGO                                                NaN
# ALB                                                NaN
# AND                                                NaN
# ARG                                                NaN
# ARM                                                NaN
# ATG                                                NaN
# AUS                                                NaN
# AUT                                                NaN
# AZE                                                NaN
# BDI                                                NaN
# BEL                                                NaN
# BEN                                                NaN
# BFA                                                NaN
# BGD                                                NaN
# BGR                                                NaN
# BHR                                                NaN
# BHS                                                NaN
# BIH                                                NaN
# BLR                                                NaN
# BLZ                                                NaN
# BOL                                                NaN
# BRA                                                NaN
# BRB                                                NaN
# BRN                                                NaN
# BTN                                                NaN
# BWA                                                NaN
# CAF                                                NaN
# CAN                                                NaN
# CHL                                                NaN
# CHN                                                NaN
# CIV                                                NaN
# CMR                                                NaN
# COD                                                NaN
# COG                                                NaN
# COL                                                NaN
# COM                                                NaN
# CPV                                                NaN
# CRI                                                NaN
# CUB                                                NaN
# CYP                                                NaN
# CZE                                                NaN
# DEU                                                NaN
# DJI                                             75.288
# DMA                                                NaN
# DNK                                                NaN
# DOM                                                NaN
# DZA                                                NaN
# ECU                                                NaN
# EGY                                                NaN
#
#      Gross enrolment ratio, secondary (% of secondary school-age population)  \
# AFG                                                NaN
# AGO                                                NaN
# ALB                                                NaN
# AND                                                NaN
# ARG                                                NaN
# ARM                                                NaN
# ATG                                                NaN
# AUS                                                NaN
# AUT                                                NaN
# AZE                                                NaN
# BDI                                                NaN
# BEL                                                NaN
# BEN                                                NaN
# BFA                                                NaN
# BGD                                                NaN
# BGR                                                NaN
# BHR                                                NaN
# BHS                                                NaN
# BIH                                                NaN
# BLR                                                NaN
# BLZ                                                NaN
# BOL                                                NaN
# BRA                                                NaN
# BRB                                                NaN
# BRN                                                NaN
# BTN                                                NaN
# BWA                                                NaN
# CAF                                                NaN
# CAN                                                NaN
# CHL                                                NaN
# CHN                                                NaN
# CIV                                                NaN
# CMR                                                NaN
# COD                                                NaN
# COG                                                NaN
# COL                                                NaN
# COM                                                NaN
# CPV                                                NaN
# CRI                                                NaN
# CUB                                                NaN
# CYP                                                NaN
# CZE                                                NaN
# DEU                                                NaN
# DJI                                             51.971
# DMA                                                NaN
# DNK                                                NaN
# DOM                                                NaN
# DZA                                                NaN
# ECU                                                NaN
# EGY                                                NaN
#
#      Gross enrolment ratio, pre-primary (% of preschool-age children)
# AFG                                                NaN
# AGO                                                NaN
# ALB                                                NaN
# AND                                                NaN
# ARG                                                NaN
# ARM                                                NaN
# ATG                                                NaN
# AUS                                                NaN
# AUT                                                NaN
# AZE                                                NaN
# BDI                                                NaN
# BEL                                                NaN
# BEN                                                NaN
# BFA                                                NaN
# BGD                                                NaN
# BGR                                                NaN
# BHR                                                NaN
# BHS                                                NaN
# BIH                                                NaN
# BLR                                                NaN
# BLZ                                                NaN
# BOL                                                NaN
# BRA                                                NaN
# BRB                                                NaN
# BRN                                                NaN
# BTN                                                NaN
# BWA                                                NaN
# CAF                                                NaN
# CAN                                                NaN
# CHL                                                NaN
# CHN                                                NaN
# CIV                                                NaN
# CMR                                                NaN
# COD                                                NaN
# COG                                                NaN
# COL                                                NaN
# COM                                                NaN
# CPV                                                NaN
# CRI                                                NaN
# CUB                                                NaN
# CYP                                                NaN
# CZE                                                NaN
# DEU                                                NaN
# DJI                                               9.18
# DMA                                                NaN
# DNK                                                NaN
# DOM                                                NaN
# DZA                                                NaN
# ECU                                                NaN
# EGY                                                NaN
#
# [50 rows x 89 columns]
